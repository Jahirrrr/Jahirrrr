# %% [markdown]
# # LLM Finetuning using AutoTrain Advanced
#
# In this notebook, we will finetune a llama-3.2-1b-instruct model using AutoTrain Advanced.
# You can replace the model with any Hugging Face transformers compatible model and dataset with any other dataset in proper formatting.
# For dataset formatting, please take a look at [docs](https://huggingface.co/docs/autotrain/index).

# %%
from autotrain.params import LLMTrainingParams
from autotrain.project import AutoTrainProject

# %%
params = LLMTrainingParams(
    model="meta-llama/Llama-3.2-1B-Instruct",
    data_path="HuggingFaceH4/no_robots", # path to the dataset on huggingface hub
    chat_template="tokenizer", # using the chat template defined in the model's tokenizer
    text_column="messages", # the column in the dataset that contains the text
    train_split="train",
    trainer="sft", # using the SFT trainer, choose from sft, default, orpo, dpo and reward
    epochs=1,
    batch_size=1,
    lr=1e-5,
    peft=True, # training LoRA using PEFT
    quantization="int4", # using int4 quantization
    target_modules="all-linear",
    padding="right",
    optimizer="paged_adamw_8bit",
    scheduler="cosine",
    gradient_accumulation=8,
    mixed_precision="bf16",
    merge_adapter=True,
    project_name="autotrain-llama32-1b-finetune",
    log="tensorboard",
    push_to_hub=True,
    username="Jahirrrr",
    token="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",
)

# %%
# !autotrain llm \
   --train \
   --project_name demo-proj-test-syalalalalala \
   --model openai-community/gpt2 \
   --data_path minhalvp/islamqa \
   --peft \
   --batch-size 2 \
   --epochs 1 \
   --trainer sft \
   --model-max-length 512 \
   --text-column Question \
   --push_to_hub \
   --username="Jahirrrr" \
   --token="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"
# Out:
# INFO     | 2024-12-22 07:49:36 | autotrain.cli.run_llm:run:136 - Running LLM
# WARNING  | 2024-12-22 07:49:36 | autotrain.trainers.common:__init__:286 - Parameters supplied but not used: inference, backend, func, train, deploy, config, version
# INFO     | 2024-12-22 07:49:36 | autotrain.backends.local:create:20 - Starting local training...
# INFO     | 2024-12-22 07:49:36 | autotrain.commands:launch_command:514 - ['accelerate', 'launch', '--num_machines', '1', '--num_processes', '1', '--mixed_precision', 'no', '-m', 'autotrain.trainers.clm', '--training_config', 'demo-proj-test-syalalalalala/training_params.json']
# INFO     | 2024-12-22 07:49:36 | autotrain.commands:launch_command:515 - {'model': 'openai-community/gpt2', 'project_name': 'demo-proj-test-syalalalalala', 'data_path': 'minhalvp/islamqa', 'train_split': 'train', 'valid_split': None, 'add_eos_token': True, 'block_size': 1024, 'model_max_length': 512, 'padding': 'right', 'trainer': 'sft', 'use_flash_attention_2': False, 'log': 'none', 'disable_gradient_checkpointing': False, 'logging_steps': -1, 'eval_strategy': 'epoch', 'save_total_limit': 1, 'auto_find_batch_size': False, 'mixed_precision': None, 'lr': 3e-05, 'epochs': 1, 'batch_size': 2, 'warmup_ratio': 0.1, 'gradient_accumulation': 4, 'optimizer': 'adamw_torch', 'scheduler': 'linear', 'weight_decay': 0.0, 'max_grad_norm': 1.0, 'seed': 42, 'chat_template': None, 'quantization': 'int4', 'target_modules': 'all-linear', 'merge_adapter': False, 'peft': True, 'lora_r': 16, 'lora_alpha': 32, 'lora_dropout': 0.05, 'model_ref': None, 'dpo_beta': 0.1, 'max_prompt_length': 128, 'max_completion_length': None, 'prompt_text_column': None, 'text_column': 'Question', 'rejected_text_column': None, 'push_to_hub': True, 'username': 'Jahirrrr', 'token': '*****', 'unsloth': False, 'distributed_backend': None}
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# INFO     | 2024-12-22 07:49:49 | autotrain.trainers.clm.train_clm_sft:train:11 - Starting SFT training...
# INFO     | 2024-12-22 07:49:53 | autotrain.trainers.clm.utils:process_input_data:550 - Train data: Dataset({
#     features: ['Question', 'Full Answer'],
#     num_rows: 3355
# })
# INFO     | 2024-12-22 07:49:53 | autotrain.trainers.clm.utils:process_input_data:551 - Valid data: None
# INFO     | 2024-12-22 07:49:53 | autotrain.trainers.clm.utils:configure_logging_steps:671 - configuring logging steps
# INFO     | 2024-12-22 07:49:53 | autotrain.trainers.clm.utils:configure_logging_steps:684 - Logging steps: 25
# INFO     | 2024-12-22 07:49:53 | autotrain.trainers.clm.utils:configure_training_args:723 - configuring training args
# INFO     | 2024-12-22 07:49:53 | autotrain.trainers.clm.utils:configure_block_size:801 - Using block size 1024
# INFO     | 2024-12-22 07:49:54 | autotrain.trainers.clm.utils:get_model:877 - Can use unsloth: False
# WARNING  | 2024-12-22 07:49:54 | autotrain.trainers.clm.utils:get_model:919 - Unsloth not available, continuing without it...
# INFO     | 2024-12-22 07:49:54 | autotrain.trainers.clm.utils:get_model:921 - loading model config...
# INFO     | 2024-12-22 07:49:54 | autotrain.trainers.clm.utils:get_model:929 - loading model...
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# INFO     | 2024-12-22 07:49:55 | autotrain.trainers.clm.utils:get_model:960 - model dtype: torch.float16
# INFO     | 2024-12-22 07:49:55 | autotrain.trainers.clm.train_clm_sft:train:39 - creating trainer
# Generating train split: 292 examples [00:00, 371.66 examples/s]
# INFO     | 2024-12-22 07:49:57 | autotrain.trainers.common:on_train_begin:386 - Starting to train...
#  69% 25/36 [01:06<00:29,  2.70s/it]INFO     | 2024-12-22 07:51:04 | autotrain.trainers.common:on_log:367 - {'loss': 14.7887, 'grad_norm': 1.5257153511047363, 'learning_rate': 1.03125e-05, 'epoch': 0.684931506849315}
# {'loss': 14.7887, 'grad_norm': 1.5257153511047363, 'learning_rate': 1.03125e-05, 'epoch': 0.68}
# 100% 36/36 [01:36<00:00,  2.71s/it]INFO     | 2024-12-22 07:51:34 | autotrain.trainers.common:on_log:367 - {'train_runtime': 96.6564, 'train_samples_per_second': 3.021, 'train_steps_per_second': 0.372, 'train_loss': 14.721036275227865, 'epoch': 0.9863013698630136}
# {'train_runtime': 96.6564, 'train_samples_per_second': 3.021, 'train_steps_per_second': 0.372, 'train_loss': 14.721036275227865, 'epoch': 0.99}
# 100% 36/36 [01:36<00:00,  2.68s/it]
# INFO     | 2024-12-22 07:51:34 | autotrain.trainers.clm.utils:post_training_steps:416 - Finished training, saving model...
# INFO     | 2024-12-22 07:51:34 | autotrain.trainers.clm.utils:post_training_steps:449 - Pushing model to hub...
# adapter_model.safetensors:   0% 0.00/9.45M [00:00<?, ?B/s]
# Upload 2 LFS files:   0% 0/2 [00:00<?, ?it/s]
#
# training_args.bin: 100% 5.62k/5.62k [00:00<00:00, 19.6kB/s]
# adapter_model.safetensors: 100% 9.45M/9.45M [00:00<00:00, 13.5MB/s]
#
# Upload 2 LFS files: 100% 2/2 [00:00<00:00,  2.08it/s]
# INFO     | 2024-12-22 07:51:42 | autotrain.cli.run_llm:run:141 - Job ID: 2623

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_path = "Jahirrrr/demo-proj-test-syalalalalala"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(
    model_path,
    device_map="auto",
    torch_dtype='auto'
).eval()

# Prompt content: "hi"
messages = [
    {"role": "user", "content": "hi"}
]

input_ids = tokenizer.apply_chat_template(conversation=messages, tokenize=True, add_generation_prompt=True, return_tensors='pt')
output_ids = model.generate(input_ids.to('cuda'))
response = tokenizer.decode(output_ids[0][input_ids.shape[1]:], skip_special_tokens=True)

# Model response: "Hello! How can I assist you today?"
print(response)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/824 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/131 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/layer.py:1264: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# adapter_model.safetensors:   0%|          | 0.00/9.45M [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# <|im_end|>user
#
# <|im_start|>assistant

# %%
# !autotrain llm --help
# Out:
# usage: autotrain <command> [<args>] llm [-h] [--train] [--deploy] [--inference]
#                                         [--backend BACKEND] [--model MODEL]
#                                         [--project-name PROJECT_NAME] [--data-path DATA_PATH]
#                                         [--train-split TRAIN_SPLIT] [--valid-split VALID_SPLIT]
#                                         [--add-eos-token] [--model-max-length MODEL_MAX_LENGTH]
#                                         [--padding PADDING] [--trainer TRAINER]
#                                         [--use-flash-attention-2] [--log LOG]
#                                         [--disable-gradient-checkpointing]
#                                         [--logging-steps LOGGING_STEPS]
#                                         [--eval-strategy EVAL_STRATEGY]
#                                         [--save-total-limit SAVE_TOTAL_LIMIT]
#                                         [--auto-find-batch-size]
#                                         [--mixed-precision MIXED_PRECISION] [--lr LR]
#                                         [--epochs EPOCHS] [--batch-size BATCH_SIZE]
#                                         [--warmup-ratio WARMUP_RATIO]
#                                         [--gradient-accumulation GRADIENT_ACCUMULATION]
#                                         [--optimizer OPTIMIZER] [--scheduler SCHEDULER]
#                                         [--weight-decay WEIGHT_DECAY]
#                                         [--max-grad-norm MAX_GRAD_NORM] [--seed SEED]
#                                         [--chat-template CHAT_TEMPLATE]
#                                         [--quantization QUANTIZATION]
#                                         [--target-modules TARGET_MODULES] [--merge-adapter]
#                                         [--peft] [--lora-r LORA_R] [--lora-alpha LORA_ALPHA]
#                                         [--lora-dropout LORA_DROPOUT] [--model-ref MODEL_REF]
#                                         [--dpo-beta DPO_BETA]
#                                         [--max-prompt-length MAX_PROMPT_LENGTH]
#                                         [--max-completion-length MAX_COMPLETION_LENGTH]
#                                         [--prompt-text-column PROMPT_TEXT_COLUMN]
#                                         [--text-column TEXT_COLUMN]
#                                         [--rejected-text-column REJECTED_TEXT_COLUMN]
#                                         [--push-to-hub] [--username USERNAME] [--token TOKEN]
#                                         [--unsloth] [--distributed-backend DISTRIBUTED_BACKEND]
#                                         [--block_size BLOCK_SIZE]
#
# ✨ Run AutoTrain LLM
#
# options:
#   -h, --help            show this help message and exit
#   --train               Command to train the model
#   --deploy              Command to deploy the model (limited availability)
#   --inference           Command to run inference (limited availability)
#   --backend BACKEND     Backend
#   --model MODEL, --model MODEL, --model MODEL
#                         Model name to be used for training
#   --project-name PROJECT_NAME, --project_name PROJECT_NAME, --project-name PROJECT_NAME
#                         Name of the project and output directory
#   --data-path DATA_PATH, --data_path DATA_PATH, --data-path DATA_PATH
#                         Path to the dataset
#   --train-split TRAIN_SPLIT, --train_split TRAIN_SPLIT, --train-split TRAIN_SPLIT
#                         Configuration for the training data split
#   --valid-split VALID_SPLIT, --valid_split VALID_SPLIT, --valid-split VALID_SPLIT
#                         Configuration for the validation data split
#   --add-eos-token, --add_eos_token, --add-eos-token
#                         Whether to add an EOS token at the end of sequences
#   --model-max-length MODEL_MAX_LENGTH, --model_max_length MODEL_MAX_LENGTH, --model-max-length MODEL_MAX_LENGTH
#                         Maximum length of the model input
#   --padding PADDING, --padding PADDING, --padding PADDING
#                         Side on which to pad sequences (left or right)
#   --trainer TRAINER, --trainer TRAINER, --trainer TRAINER
#                         Type of trainer to use
#   --use-flash-attention-2, --use_flash_attention_2, --use-flash-attention-2
#                         Whether to use flash attention version 2
#   --log LOG, --log LOG, --log LOG
#                         Logging method for experiment tracking
#   --disable-gradient-checkpointing, --disable_gradient_checkpointing, --disable-gradient-checkpointing
#                         Whether to disable gradient checkpointing
#   --logging-steps LOGGING_STEPS, --logging_steps LOGGING_STEPS, --logging-steps LOGGING_STEPS
#                         Number of steps between logging events
#   --eval-strategy EVAL_STRATEGY, --eval_strategy EVAL_STRATEGY, --eval-strategy EVAL_STRATEGY
#                         Strategy for evaluation (e.g., 'epoch')
#   --save-total-limit SAVE_TOTAL_LIMIT, --save_total_limit SAVE_TOTAL_LIMIT, --save-total-limit SAVE_TOTAL_LIMIT
#                         Maximum number of checkpoints to keep
#   --auto-find-batch-size, --auto_find_batch_size, --auto-find-batch-size
#                         Whether to automatically find the optimal batch size
#   --mixed-precision MIXED_PRECISION, --mixed_precision MIXED_PRECISION, --mixed-precision MIXED_PRECISION
#                         Type of mixed precision to use (e.g., 'fp16', 'bf16', or None)
#   --lr LR, --lr LR, --lr LR
#                         Learning rate for training
#   --epochs EPOCHS, --epochs EPOCHS, --epochs EPOCHS
#                         Number of training epochs
#   --batch-size BATCH_SIZE, --batch_size BATCH_SIZE, --batch-size BATCH_SIZE
#                         Batch size for training
#   --warmup-ratio WARMUP_RATIO, --warmup_ratio WARMUP_RATIO, --warmup-ratio WARMUP_RATIO
#                         Proportion of training to perform learning rate warmup
#   --gradient-accumulation GRADIENT_ACCUMULATION, --gradient_accumulation GRADIENT_ACCUMULATION, --gradient-accumulation GRADIENT_ACCUMULATION
#                         Number of steps to accumulate gradients before updating
#   --optimizer OPTIMIZER, --optimizer OPTIMIZER, --optimizer OPTIMIZER
#                         Optimizer to use for training
#   --scheduler SCHEDULER, --scheduler SCHEDULER, --scheduler SCHEDULER
#                         Learning rate scheduler to use
#   --weight-decay WEIGHT_DECAY, --weight_decay WEIGHT_DECAY, --weight-decay WEIGHT_DECAY
#                         Weight decay to apply to the optimizer
#   --max-grad-norm MAX_GRAD_NORM, --max_grad_norm MAX_GRAD_NORM, --max-grad-norm MAX_GRAD_NORM
#                         Maximum norm for gradient clipping
#   --seed SEED, --seed SEED, --seed SEED
#                         Random seed for reproducibility
#   --chat-template CHAT_TEMPLATE, --chat_template CHAT_TEMPLATE, --chat-template CHAT_TEMPLATE
#                         Template for chat-based models, options include: None, zephyr, chatml, or
#                         tokenizer
#   --quantization QUANTIZATION, --quantization QUANTIZATION, --quantization QUANTIZATION
#                         Quantization method to use (e.g., 'int4', 'int8', or None)
#   --target-modules TARGET_MODULES, --target_modules TARGET_MODULES, --target-modules TARGET_MODULES
#                         Target modules for quantization or fine-tuning
#   --merge-adapter, --merge_adapter, --merge-adapter
#                         Whether to merge the adapter layers
#   --peft, --peft, --peft
#                         Whether to use Parameter-Efficient Fine-Tuning (PEFT)
#   --lora-r LORA_R, --lora_r LORA_R, --lora-r LORA_R
#                         Rank of the LoRA matrices
#   --lora-alpha LORA_ALPHA, --lora_alpha LORA_ALPHA, --lora-alpha LORA_ALPHA
#                         Alpha parameter for LoRA
#   --lora-dropout LORA_DROPOUT, --lora_dropout LORA_DROPOUT, --lora-dropout LORA_DROPOUT
#                         Dropout rate for LoRA
#   --model-ref MODEL_REF, --model_ref MODEL_REF, --model-ref MODEL_REF
#                         Reference model for DPO trainer
#   --dpo-beta DPO_BETA, --dpo_beta DPO_BETA, --dpo-beta DPO_BETA
#                         Beta parameter for DPO trainer
#   --max-prompt-length MAX_PROMPT_LENGTH, --max_prompt_length MAX_PROMPT_LENGTH, --max-prompt-length MAX_PROMPT_LENGTH
#                         Maximum length of the prompt
#   --max-completion-length MAX_COMPLETION_LENGTH, --max_completion_length MAX_COMPLETION_LENGTH, --max-completion-length MAX_COMPLETION_LENGTH
#                         Maximum length of the completion
#   --prompt-text-column PROMPT_TEXT_COLUMN, --prompt_text_column PROMPT_TEXT_COLUMN, --prompt-text-column PROMPT_TEXT_COLUMN
#                         Column name for the prompt text
#   --text-column TEXT_COLUMN, --text_column TEXT_COLUMN, --text-column TEXT_COLUMN
#                         Column name for the text data
#   --rejected-text-column REJECTED_TEXT_COLUMN, --rejected_text_column REJECTED_TEXT_COLUMN, --rejected-text-column REJECTED_TEXT_COLUMN
#                         Column name for the rejected text data
#   --push-to-hub, --push_to_hub, --push-to-hub
#                         Whether to push the model to the Hugging Face Hub
#   --username USERNAME, --username USERNAME, --username USERNAME
#                         Hugging Face username for authentication
#   --token TOKEN, --token TOKEN, --token TOKEN
#                         Hugging Face token for authentication
#   --unsloth, --unsloth, --unsloth
#                         Whether to use the unsloth library
#   --distributed-backend DISTRIBUTED_BACKEND, --distributed_backend DISTRIBUTED_BACKEND, --distributed-backend DISTRIBUTED_BACKEND
#                         Backend to use for distributed training
#   --block_size BLOCK_SIZE, --block-size BLOCK_SIZE
#                         Block size

# %%
import os

from autotrain.params import LLMTrainingParams
from autotrain.project import AutoTrainProject


params = LLMTrainingParams(
    model="openai-community/gpt2",
    data_path="HuggingFaceH4/no_robots",
    chat_template="tokenizer",
    text_column="messages",
    train_split="train",
    trainer="sft",
    epochs=1,
    batch_size=1,
    lr=1e-5,
    peft=False,
    quantization="int4",
    target_modules="all-linear",
    padding="right",
    optimizer="paged_adamw_8bit",
    scheduler="cosine",
    gradient_accumulation=8,
    mixed_precision="bf16",
    merge_adapter=True,
    project_name="autotrain-llama32-1b-finetune",
    log="tensorboard",
    push_to_hub=True,
    username="Jahirrrr",
    token="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",
)


backend = "local"
project = AutoTrainProject(params=params, backend=backend, process=True)
project.create()
# Out:
# INFO     | 2024-12-22 07:33:46 | autotrain.backends.local:create:20 - Starting local training...
# WARNING  | 2024-12-22 07:33:46 | autotrain.commands:get_accelerate_command:58 - No GPU found. Forcing training on CPU. This will be super slow!
# INFO     | 2024-12-22 07:33:46 | autotrain.commands:launch_command:514 - ['accelerate', 'launch', '--cpu', '-m', 'autotrain.trainers.clm', '--training_config', 'autotrain-llama32-1b-finetune/training_params.json', '-m', 'autotrain.trainers.clm', '--training_config', 'autotrain-llama32-1b-finetune/training_params.json', '-m', 'autotrain.trainers.clm', '--training_config', 'autotrain-llama32-1b-finetune/training_params.json']
# INFO     | 2024-12-22 07:33:46 | autotrain.commands:launch_command:515 - {'model': 'openai-community/gpt2', 'project_name': 'autotrain-llama32-1b-finetune', 'data_path': 'HuggingFaceH4/no_robots', 'train_split': 'train', 'valid_split': None, 'add_eos_token': True, 'block_size': -1, 'model_max_length': 2048, 'padding': 'right', 'trainer': 'sft', 'use_flash_attention_2': False, 'log': 'tensorboard', 'disable_gradient_checkpointing': False, 'logging_steps': -1, 'eval_strategy': 'epoch', 'save_total_limit': 1, 'auto_find_batch_size': False, 'mixed_precision': 'bf16', 'lr': 1e-05, 'epochs': 1, 'batch_size': 1, 'warmup_ratio': 0.1, 'gradient_accumulation': 8, 'optimizer': 'paged_adamw_8bit', 'scheduler': 'cosine', 'weight_decay': 0.0, 'max_grad_norm': 1.0, 'seed': 42, 'chat_template': 'tokenizer', 'quantization': 'int4', 'target_modules': 'all-linear', 'merge_adapter': True, 'peft': False, 'lora_r': 16, 'lora_alpha': 32, 'lora_dropout': 0.05, 'model_ref': None, 'dpo_beta': 0.1, 'max_prompt_length': 128, 'max_completion_length': None, 'prompt_text_column': None, 'text_column': 'messages', 'rejected_text_column': None, 'push_to_hub': True, 'username': 'Jahirrrr', 'token': '*****', 'unsloth': False, 'distributed_backend': None}
# 7868

# %% [markdown]
# If your dataset is in CSV / JSONL format (JSONL is most preferred) and is stored locally, make the following changes to `params`:
#
# ```python
# params = LLMTrainingParams(
#     data_path="data/", # this is the path to folder where train.jsonl/train.csv is located
#     text_column="text", # this is the column name in the CSV/JSONL file which contains the text
#     train_split = "train" # this is the filename without extension
#     .
#     .
#     .
# )
# ```

# %%
# this will train the model locally
project = AutoTrainProject(params=params, backend="local", process=True)
project.create()
# Out:
# INFO     | 2024-12-22 07:06:10 | autotrain.backends.local:create:20 - Starting local training...
# WARNING  | 2024-12-22 07:06:10 | autotrain.commands:get_accelerate_command:58 - No GPU found. Forcing training on CPU. This will be super slow!
# INFO     | 2024-12-22 07:06:10 | autotrain.commands:launch_command:514 - ['accelerate', 'launch', '--cpu', '-m', 'autotrain.trainers.clm', '--training_config', 'autotrain-llama32-1b-finetune/training_params.json']
# INFO     | 2024-12-22 07:06:10 | autotrain.commands:launch_command:515 - {'model': 'meta-llama/Llama-3.2-1B-Instruct', 'project_name': 'autotrain-llama32-1b-finetune', 'data_path': 'HuggingFaceH4/no_robots', 'train_split': 'train', 'valid_split': None, 'add_eos_token': True, 'block_size': -1, 'model_max_length': 2048, 'padding': 'right', 'trainer': 'sft', 'use_flash_attention_2': False, 'log': 'tensorboard', 'disable_gradient_checkpointing': False, 'logging_steps': -1, 'eval_strategy': 'epoch', 'save_total_limit': 1, 'auto_find_batch_size': False, 'mixed_precision': 'bf16', 'lr': 1e-05, 'epochs': 1, 'batch_size': 1, 'warmup_ratio': 0.1, 'gradient_accumulation': 8, 'optimizer': 'paged_adamw_8bit', 'scheduler': 'cosine', 'weight_decay': 0.0, 'max_grad_norm': 1.0, 'seed': 42, 'chat_template': 'tokenizer', 'quantization': 'int4', 'target_modules': 'all-linear', 'merge_adapter': True, 'peft': True, 'lora_r': 16, 'lora_alpha': 32, 'lora_dropout': 0.05, 'model_ref': None, 'dpo_beta': 0.1, 'max_prompt_length': 128, 'max_completion_length': None, 'prompt_text_column': None, 'text_column': 'messages', 'rejected_text_column': None, 'push_to_hub': True, 'username': 'Jahirrrr', 'token': '*****', 'unsloth': False, 'distributed_backend': None}
# 1215
